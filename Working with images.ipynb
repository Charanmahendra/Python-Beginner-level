# %%
from PIL import Image

# %%
mac=Image.open('1.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x550 at 0x1FDAEEF09E8>

# %%
mac.show()

# %%
mac.size
# Out:
# (750, 550)

# %%
mac.filename
# Out:
# '1.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
nac=Image.open('17.jpg')

# %%
nac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x1FDAEFCB828>

# %%
nac.crop((0,0,300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1FDAF080080>

# %%
nac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1FDAF080240>

# %%
x=0
y=0

w=750/3
h=550/10

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=250x55 at 0x1FDAF1311D0>

# %%
halfway=750/2

# %%
x=halfway-200
w=halfway+200

# %%
y=200
h=550

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x350 at 0x1FDAF131470>

# %%
mouse=mac.crop((x,y,w,h))

# %%
mac.paste(im=mouse,box=(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x550 at 0x1FDAEEF09E8>

# %%
from PIL import Image

# %%
words=Image.open("word_matrix.png")

# %%
mask=Image.open("mask.png")

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1FDAF13AB00>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x1FDAF13ABA8>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask=mask.resize((1015,559))

# %%
mask.size
# Out:
# (1015, 559)

# %%
mask.putalpha(200)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x1FDAF13ADD8>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1FDAF13AB00>
